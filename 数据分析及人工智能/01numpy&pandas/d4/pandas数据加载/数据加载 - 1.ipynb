# %% [markdown]
# ### pandas提供了一些用于将表格型数据读取为DataFrame对象的函数，期中read_csv和read_table这两个使用最多

# %% [markdown]
# 使用read_csv将其读入

# %%
import pandas as pd
from pandas import Series,DataFrame

import numpy as np

# %%
sms = pd.read_csv('./data/SMSSpamCollection', sep='\t',  header=None)
sms.head()
# Out:
#       0                                                  1
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# 使用read_table读取

# %%
pd.read_table('./data/SMSSpamCollection', header=None)
# Out:
# e:\1901\.env\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
#          0                                                  1
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# 5     spam  FreeMsg Hey there darling it's been 3 week's n...
# 6      ham  Even my brother is not like to speak with me. ...
# 7      ham  As per your request 'Melle Melle (Oru Minnamin...
# 8     spam  WINNER!! As a valued network customer you have...
# 9     spam  Had your mobile 11 months or more? U R entitle...
# 10     ham  I'm gonna be home soon and i don't want to tal...
# ...

# %%
pd.read_csv('./type-.txt', sep='-', header=None)
# Out:
#     0   1    2
# 0  你好  我好  他也好
# 1  也许  大概  有可能
# 2  然而  未必  不见得

# %%
# !pip install xlrd -i https://pypi.douban.com/simple
# Out:
# Looking in indexes: https://pypi.douban.com/simple
# ...

# %%
# 读取excel表格
pd.read_excel('./read_xlsx.xlsx', sheet_name=2)
# Out:
#   Unnamed: 0 Unnamed: 1  期中 Unnamed: 3 Unnamed: 4  期末 Unnamed: 6 Unnamed: 7
# 0        NaN        NaN  语文         数学         英语  语文         数学         英语
# 1         一班         张三  12         34         66  73         12         34
# 2        NaN         李四  56         35         67  74         13         35
# 3        NaN        王老五  56         36         68  75         14         36
# 4         二班         张三  45         37         69  76         15         37
# 5        NaN         李四  34         38         70  77         16         38
# 6        NaN        王老五  65         39         71  78         17         39

# %% [markdown]
# 读取sqlite文件

# %%
import sqlite3

# %%
conn = sqlite3.connect('./data.sqlite')
conn

# %% [markdown]
# 导包sqlite3

# %% [markdown]
# 读取table
#  pd.read_sql("sql语句", con)

# %%
weather_2017 = pd.read_sql('select * from weather_2017 limit 30', conn, index_col='index')
weather_2017
# Out:
#                  Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# index
# 0      2012-01-01 00:00:00      -1.8                -3.9           86
# 1      2012-01-01 01:00:00      -1.8                -3.7           87
# 2      2012-01-01 02:00:00      -1.8                -3.4           89
# 3      2012-01-01 03:00:00      -1.5                -3.2           88
# 4      2012-01-01 04:00:00      -1.5                -3.3           88
# 5      2012-01-01 05:00:00      -1.4                -3.3           87
# 6      2012-01-01 06:00:00      -1.5                -3.1           89
# 7      2012-01-01 07:00:00      -1.4                -3.6           85
# 8      2012-01-01 08:00:00      -1.4                -3.6           85
# 9      2012-01-01 09:00:00      -1.3                -3.1           88
# 10     2012-01-01 10:00:00      -1.0                -2.3           91
# 11     2012-01-01 11:00:00      -0.5                -2.1           89
# ...

# %% [markdown]
# 设置行索引index_col

# %% [markdown]
# 写入sql文件

# %%
weather_2017.to_csv('./weather_2017.csv')

# %%
weather_2017.to_json('./weather_2017.json')

# %%
weather_2017.to_html('./weather_2017.html')

# %%
weather_2017.to_sql('weather_2019', conn, if_exists='append')
# Out:
# e:\1901\.env\lib\site-packages\pandas\core\generic.py:2531: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype, method=method)

# %%
pd.read_sql('select * from weather_2019', conn)
# Out:
#     index            Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0       0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1       1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2       2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3       3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4       4  2012-01-01 04:00:00      -1.5                -3.3           88
# 5       5  2012-01-01 05:00:00      -1.4                -3.3           87
# 6       6  2012-01-01 06:00:00      -1.5                -3.1           89
# 7       7  2012-01-01 07:00:00      -1.4                -3.6           85
# 8       8  2012-01-01 08:00:00      -1.4                -3.6           85
# 9       9  2012-01-01 09:00:00      -1.3                -3.1           88
# 10     10  2012-01-01 10:00:00      -1.0                -2.3           91
# 11     11  2012-01-01 11:00:00      -0.5                -2.1           89
# ...

# %%
import pymysql

# %%
# !pip install pymysql

# %%
conn = pymysql.connect(host='127.0.0.1', port=3306, user='root', password='root', database='maoyan', charset='utf8')
conn

# %%
maoyan = pd.read_sql('select * from top limit 30', conn)

# %%
maoyan.to_sql('top_30', conn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\1901\.env\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# e:\1901\.env\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     167
# --> 168         query = self.mogrify(query, args)
#     169
#
# e:\1901\.env\lib\site-packages\pymysql\cursors.py in mogrify(self, query, args)
#     146         if args is not None:
# --> 147             query = query % self._escape_args(args, conn)
#     148
#
# TypeError: not all arguments converted during string formatting
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-30-434015c26a42> in <module>
# ...

# %%
# !pip install mysqlclient -i https://pypi.douban.com/simple
# Out:
# Looking in indexes: https://pypi.douban.com/simple
# ...

# %%
# !pip install sqlalchemy -i https://pypi.douban.com/simple
# Out:
# Looking in indexes: https://pypi.douban.com/simple
# ...
#   Stored in directory: C:\Users\Administrator\AppData\Local\pip\Cache\wheels\8a\dd\8d\be2e9bc60bd0612ba0f5f0d2062954d5687ab39196000bc7e0
# Successfully built sqlalchemy
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqldb://root:root@localhost:3306/maoyan?charset=utf8')

# %%
engine = create_engine('mysql+pymysql://root:root@localhost/maoyan?charset=utf8')

# %%
maoyan.to_sql('top_30', engine)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-030bd180cb19> in <module>
# ----> 1 maoyan.to_sql('top_30', engine)
#
# e:\1901\.env\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# e:\1901\.env\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# ...

# %% [markdown]
# 根据url获取网络上的数据

# %%
pd.read_csv('https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv')
# Out:
#           Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0   2012-12-05         -7426            -6060         -1367     -74
# 1   2012-12-12         -8783            -7520         -1263     123
# 2   2012-12-19         -5496            -5470           -26     -73
# 3   2012-12-26         -4451            -4076          -375     550
# 4   2013-01-02        -11156            -9622         -1533    -158
# 5   2013-01-09         14817             7995          6821    2888
# 6   2014-04-02          3155              938          2217     265
# 7   2014-04-09          5761             2080          3681    1482
# 8   2014-04-16          2286              634          1652    1186
# 9   2014-04-23          3530             1392          2138    1239
# 10  2014-04-30         -3890            -3996           106     759
# 11  2014-05-07           632            -2006          2639    -340
# 12  2014-05-14         -1079            -2321          1242    1188
# ...
