# %% [markdown]
# # 美国2012年总统候选人政治献金数据分析

# %% [markdown]
# 导入包

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 方便大家操作，将月份和参选人以及所在政党进行定义

# %%
months = {'JAN' : 1, 'FEB' : 2, 'MAR' : 3, 'APR' : 4, 'MAY' : 5, 'JUN' : 6,
          'JUL' : 7, 'AUG' : 8, 'SEP' : 9, 'OCT': 10, 'NOV': 11, 'DEC' : 12}
of_interest = ['Obama, Barack', 'Romney, Mitt', 'Santorum, Rick', 
               'Paul, Ron', 'Gingrich, Newt']
parties = {
  'Bachmann, Michelle': 'Republican',
  'Romney, Mitt': 'Republican',
  'Obama, Barack': 'Democrat',
  "Roemer, Charles E. 'Buddy' III": 'Reform',
  'Pawlenty, Timothy': 'Republican',
  'Johnson, Gary Earl': 'Libertarian',
  'Paul, Ron': 'Republican',
  'Santorum, Rick': 'Republican',
  'Cain, Herman': 'Republican',
  'Gingrich, Newt': 'Republican',
  'McCotter, Thaddeus G': 'Republican',
  'Huntsman, Jon': 'Republican',
  'Perry, Rick': 'Republican'           
 }

# %% [markdown]
# 读取文件

# %%
ele  = pd.read_csv('../data/usa_election.txt', low_memory=False)
ele.head(20)
# cand = candidate
# amount 
# contributor
# Out:
#       cmte_id    cand_id             cand_nm           contbr_nm  \
# 0   C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 1   C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 2   C00410118  P20002978  Bachmann, Michelle       SMITH, LANIER
# 3   C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 4   C00410118  P20002978  Bachmann, Michelle  WARDENBURG, HAROLD
# 5   C00410118  P20002978  Bachmann, Michelle      BECKMAN, JAMES
# 6   C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 7   C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 8   C00410118  P20002978  Bachmann, Michelle      COLLINS, SARAH
# 9   C00410118  P20002978  Bachmann, Michelle     COLEMAN, RONALD
# 10  C00410118  P20002978  Bachmann, Michelle  ATCHLEY, JR, KEITH
# 11  C00410118  P20002978  Bachmann, Michelle    FARNSWORTH, ROSS
# 12  C00410118  P20002978  Bachmann, Michelle   PRESTON, CLIFFORD
# 13  C00410118  P20002978  Bachmann, Michelle     WILSON, RICHARD
# 14  C00410118  P20002978  Bachmann, Michelle     MILLER, WILLIAM
# 15  C00410118  P20002978  Bachmann, Michelle      DOLAN, WILLIAM
# 16  C00410118  P20002978  Bachmann, Michelle    REULING, RICHARD
# 17  C00410118  P20002978  Bachmann, Michelle         PETERSEN, W
# 18  C00410118  P20002978  Bachmann, Michelle   ALLUMBAUGH, KATHY
# 19  C00410118  P20002978  Bachmann, Michelle      DEL POZO, JOSE
#
#            contbr_city contbr_st contbr_zip        contbr_employer  \
# 0               MOBILE        AL  366010290                RETIRED
# 1               MOBILE        AL  366010290                RETIRED
# 2               LANETT        AL  368633403  INFORMATION REQUESTED
# 3              PIGGOTT        AR  724548253                   NONE
# 4   HOT SPRINGS NATION        AR  719016467                   NONE
# 5           SPRINGDALE        AR  727647190                   NONE
# 6              PIGGOTT        AR  724548253  INFORMATION REQUESTED
# 7              PIGGOTT        AR  724548253                   NONE
# 8                 MESA        AZ  852106725    ST. JOSEPH HOSPITAL
# 9               TUCSON        AZ  857498865               RAYTHEON
# 10                MESA        AZ      85215                   NONE
# 11                MESA        AZ  852062062   FARNSWORTH COMPANIES
# 12          ORO VALLEY        AZ  857379072  INFORMATION REQUESTED
# 13           FLAGSTAFF        AZ  860010717                   NONE
# 14          SCOTTSDALE        AZ  852513055  INFORMATION REQUESTED
# 15             PHOENIX        AZ  850145248      VA MEDICAL CENTER
# 16        GREEN VALLEY        AZ  856225413                   NONE
# 17             GILBERT        AZ      85295  INFORMATION REQUESTED
# 18           SANTA ANA        CA  927051427                   NONE
# 19             DEL MAR        CA  920142938                RETIRES
#
#         contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 0                 RETIRED              250.0        20-JUN-11          NaN
# 1                 RETIRED               50.0        23-JUN-11          NaN
# 2   INFORMATION REQUESTED              250.0        05-JUL-11          NaN
# 3                 RETIRED              250.0        01-AUG-11          NaN
# 4                 RETIRED              300.0        20-JUN-11          NaN
# 5                 RETIRED              500.0        23-JUN-11          NaN
# 6   INFORMATION REQUESTED              250.0        21-JUN-11          NaN
# 7                 RETIRED              250.0        05-JUL-11          NaN
# 8                      RN              250.0        21-JUN-11          NaN
# 9     ELECTRICAL ENGINEER              250.0        20-JUN-11          NaN
# 10                RETIRED              250.0        22-JUN-11          NaN
# 11         LAND DEVELOPER              500.0        22-JUN-11          NaN
# 12  INFORMATION REQUESTED              250.0        21-JUN-11          NaN
# 13                RETIRED              500.0        17-JUN-11          NaN
# 14  INFORMATION REQUESTED              250.0        11-JUL-11          NaN
# 15              PHYSICIAN              300.0        08-JUL-11          NaN
# 16                RETIRED             1000.0        05-JUL-11          NaN
# 17  INFORMATION REQUESTED              250.0        27-JUN-11          NaN
# 18                RETIRED              250.0        13-JUN-11          NaN
# 19                RETIRED              300.0        16-JUN-11          NaN
#
#    memo_cd memo_text form_tp  file_num
# 0      NaN       NaN   SA17A    736166
# 1      NaN       NaN   SA17A    736166
# 2      NaN       NaN   SA17A    749073
# 3      NaN       NaN   SA17A    749073
# 4      NaN       NaN   SA17A    736166
# 5      NaN       NaN   SA17A    736166
# 6      NaN       NaN   SA17A    736166
# 7      NaN       NaN   SA17A    749073
# 8      NaN       NaN   SA17A    736166
# 9      NaN       NaN   SA17A    736166
# 10     NaN       NaN   SA17A    736166
# 11     NaN       NaN   SA17A    736166
# 12     NaN       NaN   SA17A    736166
# 13     NaN       NaN   SA17A    736166
# 14     NaN       NaN   SA17A    749073
# 15     NaN       NaN   SA17A    749073
# 16     NaN       NaN   SA17A    749073
# 17     NaN       NaN   SA17A    736166
# 18     NaN       NaN   SA17A    736166
# 19     NaN       NaN   SA17A    736166

# %% [markdown]
# 查看文件样式以及基本信息

# %% [markdown]
# 【知识点】使用map函数+字典，新建一列各个候选人所在党派party

# %% [markdown]
# 查看单独一行，是否加上了'party'一列

# %% [markdown]
# 使用np.unique()函数查看colums：party这一列中有哪些元素

# %% [markdown]
# 使用value_counts()函数，统计party列中各个元素出现次数

# %% [markdown]
# 【知识点】使用groupby()函数，查看各个党派收到的政治献金总数contb_receipt_amt

# %% [markdown]
# 查看具体每天各个党派收到的政治献金总数contb_receipt_amt
# 使用groupby([多个分组参数])

# %% [markdown]
# 查看日期格式，并将其转换为Pandas的日期格式,通过函数加map方式进行转换

# %% [markdown]
# 查看是否转换成功

# %% [markdown]
# 将时间转换为时间数据类型
# 根据时间进行排序

# %% [markdown]
# 得到转换后的，每天各政党所收政治献金数目。
#
# 考察知识点：groupby（多个字段）

# %% [markdown]
# 【知识点】使用unstack()将上面所得数据中的party从一级索引变成列索引,unstack('party')

# %% [markdown]
# 使用上面获取的数据
# 画出各党派累计政治献金,cumsum()累加函数

# %% [markdown]
# 把时间作为列，党派作为行来观察,unstack('contb_receipt')

# %% [markdown]
# 使用stack()把party变成二级行索引,注意所有的值都不能为nan，需要填充为0

# %% [markdown]
# 查看候选人姓名cand_nm和政治献金捐献者职业contbr_occupation，以及捐献情况。能看出各个候选人主要的支持者分布情况
# 练习：groupy，sum()求和

# %% [markdown]
# 查看老兵主要支持谁：DISABLED VETERAN
# 考察Series索引

# %% [markdown]
# 把索引变成列,Series.reset_index()

# %% [markdown]
# 找出各个候选人的捐赠者中，捐赠金额最大的人的职业以及捐献额
#
# 通过query("查询条件来查找捐献人职业")
