# %% [markdown]
# # pandas数据处理

# %% [markdown]
# ## 1、删除重复元素

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %% [markdown]
# 使用duplicated()函数检测重复的行，返回元素为布尔类型的Series对象，每个元素对应一行，如果该行不是第一次出现，则元素为True

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# 使用drop_duplicates()函数删除重复的行

# %%
df.drop_duplicates()
# Out:
#    color  size
# 0    red    10
# 1  white    20
# 3  green    30

# %% [markdown]
# 如果使用pd.concat([df1,df2],axis = 1)生成新的DataFrame，新的df中columns相同，使用duplicated()和drop_duplicates()都会出问题

# %%
#就是列名相同，当我们删除重复元素时，会出问题
df2 = pd.concat((df,df),axis = 1)
df2
# Out:
#    color  size  color  size
# 0    red    10    red    10
# 1  white    20  white    20
# 2    red    10    red    10
# 3  green    30  green    30

# %%
df2.duplicated()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-588855f0ff7b> in <module>()
# ----> 1 df2.duplicated()
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    3142
#    3143         vals = (self[col].values for col in subset)
# -> 3144         labels, shape = map(list, zip(*map(f, vals)))
#    3145
#    3146         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in f(vals)
#    3131         def f(vals):
#    3132             labels, shape = algorithms.factorize(
# -> 3133                 vals, size_hint=min(len(self), _SIZE_HINT_LIMIT))
#    3134             return labels.astype('i8', copy=False), len(shape)
#    3135
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     558     uniques = vec_klass()
#     559     check_nulls = not is_integer_dtype(original)
# --> 560     labels = table.get_labels(values, uniques, 0, na_sentinel, check_nulls)
#     561
#     562     labels = _ensure_platform_int(labels)
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.StringHashTable.get_labels (pandas/_libs/hashtable.c:19297)()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 2)

# %%
df2.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-1081ec3bd713> in <module>()
# ----> 1 df2.drop_duplicates()
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace)
#    3096         """
#    3097         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 3098         duplicated = self.duplicated(subset, keep=keep)
#    3099
#    3100         if inplace:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    3142
#    3143         vals = (self[col].values for col in subset)
# -> 3144         labels, shape = map(list, zip(*map(f, vals)))
#    3145
#    3146         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in f(vals)
#    3131         def f(vals):
#    3132             labels, shape = algorithms.factorize(
# -> 3133                 vals, size_hint=min(len(self), _SIZE_HINT_LIMIT))
#    3134             return labels.astype('i8', copy=False), len(shape)
#    3135
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     558     uniques = vec_klass()
#     559     check_nulls = not is_integer_dtype(original)
# --> 560     labels = table.get_labels(values, uniques, 0, na_sentinel, check_nulls)
#     561
#     562     labels = _ensure_platform_int(labels)
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.StringHashTable.get_labels (pandas/_libs/hashtable.c:19297)()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 2)

# %%
#drop_dupilicates ; drop 根据dupicates

# df.drop_duplicates() == 

du = df.duplicated()
#du = [0,0,1,0]
display(du)
df.drop(du)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool
#    color  size
# 2    red    10
# 3  green    30

# %%
np.logical_not(du)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
df[np.logical_not(du)]
# Out:
#    color  size
# 0    red    10
# 1  white    20
# 3  green    30

# %%
df
# Out:
#    color  size
# 0    red    10
# 1  white    20
# 2    red    10
# 3  green    30

# %% [markdown]
# ## 2. 映射

# %% [markdown]
# 映射的含义：创建一个映射关系列表，把values元素和一个特定的标签或者字符串绑定
#
# 需要使用字典：
#
# `map = {
#     'label1':'value1',
#     'label2':'value2',
#     ...
#     }
# `
#
# 包含三种操作：
#
# - replace()函数：替换元素
# - 最重要：map()函数：新建一列
# - rename()函数：替换索引

# %% [markdown]
# ### 1) replace()函数：替换元素

# %%
df*2
# Out:
#         color  size
# 0      redred    20
# 1  whitewhite    40
# 2      redred    20
# 3  greengreen    60

# %% [markdown]
# 使用replace()函数，对values进行替换操作

# %%
#red = 10
#green = 20
color = {'red':10,'green':20}

# %% [markdown]
# 首先定义一个字典

# %% [markdown]
# 调用.replace()

# %%
df.replace(color,inplace=True)

# %% [markdown]
# replace还经常用来替换NaN元素

# %%
df.loc[1] = np.nan

# %%
v = {np.nan:0.1}
df.replace(v)
# Out:
#    color  size
# 0   10.0  10.0
# 1    0.1   0.1
# 2   10.0  10.0
# 3   20.0  30.0

# %% [markdown]
# ============================================
#
# 练习19：
#
#     假设张三李四的课表里有满分的情况，老师认为是作弊，把所有满分的情况（包括150,300分）都记0分，如何实现？
#
# ============================================

# %% [markdown]
# ### 2) map()函数：新建一列

# %% [markdown]
# 使用map()函数，由已有的列生成一个新列
#
# 适合处理某一单独的列。

# %%
df = DataFrame(np.random.randint(0,150,size = (4,4)),columns=['Python','Java','PHP','HTML'],
               index = ['张三','旭日','阳刚','木兰'])
df
# Out:
#     Python  Java  PHP  HTML
# 张三      75   100   52     3
# 旭日      80   136   53   132
# 阳刚     146   106   51    72
# 木兰      35   126    2     0

# %%
#Go
#map也有映射关系，新添加一列，根据现存的那一列进行添加
v = {75:90,80:100,146:166,35:55}
df['Go'] = df['Python'].map(v)

# %%
df
# Out:
#     Python  Java  PHP  HTML   Go
# 张三      75   100   52     3   90
# 旭日      80   136   53   132  100
# 阳刚     146   106   51    72  166
# 木兰      35   126    2     0   55

# %% [markdown]
# 仍然是新建一个字典

# %% [markdown]
# map()函数中可以使用lambda函数

# %%
#C
df['C'] = df['Go'].map(lambda x : x -40)

# %%
df
# Out:
#     Python  Java  PHP  HTML   Go    C
# 张三      75   100   52     3   90   50
# 旭日      80   136   53   132  100   60
# 阳刚     146   106   51    72  166  126
# 木兰      35   126    2     0   55   15

# %%
def mp(x):
    #复杂的条件
    if x <51:
        return '不及格'
    else:
        return '优秀'

# %%
df['score'] = df['C'].map(mp)
df
# Out:
#     Python  Java  PHP  HTML   Go    C score
# 张三      75   100   52     3   90   50   不及格
# 旭日      80   136   53   132  100   60    优秀
# 阳刚     146   106   51    72  166  126    优秀
# 木兰      35   126    2     0   55   15   不及格

# %%
#'int' object is not iterable
max(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-708e89bb0f37> in <module>()
# ----> 1 max(10)
#
# TypeError: 'int' object is not iterable

# %%
#'int' object is not iterable
df['score2'] = df['C'].pma(max)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-a266d5c32b40> in <module>()
# ----> 1 df['score2'] = df['C'].map(max)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    2156         else:
#    2157             # arg is a function
# -> 2158             new_values = map_f(values, arg)
#    2159
#    2160         return self._constructor(new_values,
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer (pandas/_libs/lib.c:66645)()
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# transform()和map()类似

# %%
df['score2'] = df['C'].transform(mp)

# %%
df
# Out:
#     Python  Java  PHP  HTML   Go    C score score2
# 张三      75   100   52     3   90   50   不及格    不及格
# 旭日      80   136   53   132  100   60    优秀     优秀
# 阳刚     146   106   51    72  166  126    优秀     优秀
# 木兰      35   126    2     0   55   15   不及格    不及格

# %% [markdown]
# 使用map()函数新建一个新列

# %%
#同时map还可以修改当前列
df['C'] = df['C'].map(lambda x : x*2)

# %%
df
# Out:
#     Python  Java  PHP  HTML   Go    C score score2
# 张三      75   100   52     3   90  100   不及格    不及格
# 旭日      80   136   53   132  100  120    优秀     优秀
# 阳刚     146   106   51    72  166  252    优秀     优秀
# 木兰      35   126    2     0   55   30   不及格    不及格

# %% [markdown]
# ============================================
#
# 练习20：
#
#     新增两列，分别为张三、李四的成绩状态，如果分数低于90，则为"failed"，如果分数高于120，则为"excellent"，其他则为"pass"
#
#     【提示】使用函数作为map的参数
#
# ============================================

# %% [markdown]
# ### 3) rename()函数：替换索引

# %% [markdown]
# 仍然是新建一个字典

# %%
df
# Out:
#     Python  Java  PHP  HTML   Go    C score score2
# 张三      75   100   52     3   90  100   不及格    不及格
# 旭日      80   136   53   132  100  120    优秀     优秀
# 阳刚     146   106   51    72  166  252    优秀     优秀
# 木兰      35   126    2     0   55   30   不及格    不及格

# %%
def cols(x):
    if x == 'PHP':
        return 'php'
    if x == 'Python':
        return '大蟒蛇'
    else:
        return x

# %%
inds = {'张三':'Zhang Sir','木兰':'MissLan'}
# index, columns : scalar, list-like, dict-like or function, optional
#     Scalar or list-like will alter the ``Series.name`` attribute,
#     and raise on DataFrame or Panel.
#     dict-like or functions are transformations to apply to
#     that axis' values
df.rename(index = inds,columns=cols)
# Out:
#            大蟒蛇  Java  php  HTML   Go    C score score2
# Zhang Sir   75   100   52     3   90  100   不及格    不及格
# 旭日          80   136   53   132  100  120    优秀     优秀
# 阳刚         146   106   51    72  166  252    优秀     优秀
# MissLan     35   126    2     0   55   30   不及格    不及格

# %% [markdown]
# 使用rename()函数替换行索引

# %% [markdown]
# ## 3. 异常值检测和过滤

# %% [markdown]
# 使用describe()函数查看每一列的描述性统计量

# %%
df.describe()
# Out:
#            Python      Java       PHP        HTML          Go           C
# count    4.000000    4.0000   4.00000    4.000000    4.000000    4.000000
# mean    84.000000  117.0000  39.50000   51.750000  102.750000  125.500000
# std     45.978256   16.8523  25.01333   62.994047   46.370788   92.741576
# min     35.000000  100.0000   2.00000    0.000000   55.000000   30.000000
# 25%     65.000000  104.5000  38.75000    2.250000   81.250000   82.500000
# 50%     77.500000  116.0000  51.50000   37.500000   95.000000  110.000000
# 75%     96.500000  128.5000  52.25000   87.000000  116.500000  153.000000
# max    146.000000  136.0000  53.00000  132.000000  166.000000  252.000000

# %% [markdown]
# 使用std()函数可以求得DataFrame对象每一列的标准差

# %%
df.std()
# Out:
# Python    45.978256
# Java      16.852300
# PHP       25.013330
# HTML      62.994047
# Go        46.370788
# C         92.741576
# dtype: float64

# %% [markdown]
# 根据每一列的标准差，对DataFrame元素进行过滤。
#
# 借助any()函数, 测试是否有True，有一个或以上返回True，反之返回False
#
# 对每一列应用筛选条件,去除标准差太大的数据

# %%
df.drop(['score','score2'],axis = 1,inplace=True)

# %%
df2 = df.stack().unstack(level = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1ffcc6640855> in <module>()
# ----> 1 df2 = df.stack().unstack(level = 0)
#
# NameError: name 'df' is not defined

# %%
cond = np.abs(df2) < df2.std()*2
cond
# Out:
#            张三     旭日     阳刚     木兰
# Python   True  False  False   True
# Java    False  False   True  False
# PHP      True   True   True   True
# HTML     True  False   True   True
# Go      False  False  False   True
# C       False  False  False   True

# %%
df.std(axis = 1)
# Out:
# 张三    37.517996
# 旭日    32.420672
# 阳刚    72.923019
# 木兰    46.431311
# dtype: float64

# %%
#对数据进行过滤
#std标准方差，稳定
cond = np.abs(df) < df.std(axis = 1)*5
cond
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-8ee73a5c7431> in <module>()
#       1 #对数据进行过滤
#       2 #std标准方差，稳定
# ----> 3 cond = np.abs(df,axis = 1) < df.std(axis = 1)*5
#       4 cond
#
# TypeError: 'axis' is an invalid keyword to ufunc 'absolute'

# %%
df[cond].dropna(axis = 1)
# Out:
#     Java
# 张三   100
# 旭日   136
# 阳刚   106
# 木兰   126

# %%
df.mean()
# Out:
# Python     84.00
# Java      117.00
# PHP        39.50
# HTML       51.75
# Go        102.75
# C         125.50
# dtype: float64

# %%
df
# Out:
#     Python  Java  PHP  HTML   Go    C
# 张三      75   100   52     3   90  100
# 旭日      80   136   53   132  100  120
# 阳刚     146   106   51    72  166  252
# 木兰      35   126    2     0   55   30

# %%
#分数足够高
cond2 = np.abs(df) > df.mean()*1.2

# %%
cond&cond2
# Out:
#     Python   Java    PHP   HTML     Go      C
# 张三   False  False   True  False  False  False
# 旭日   False  False   True   True  False  False
# 阳刚    True  False   True   True   True   True
# 木兰   False  False  False  False  False  False

# %% [markdown]
# 删除特定索引df.drop(labels,inplace = True)

# %% [markdown]
# ============================================
#
# 练习21：
#
#     新建一个形状为10000*3的标准正态分布的DataFrame(np.random.randn)，去除掉所有满足以下情况的行：其中任一元素绝对值大于3倍标准差
#
# ============================================

# %%
n = np.random.randn(10000,3)

# %%
df = DataFrame(n)
df
# Out:
#              0         1         2
# 0    -1.126422 -0.919361  0.668098
# 1    -0.585425 -0.261040 -0.490388
# 2    -1.014050  0.249440  0.316363
# 3     0.729656  0.329345 -0.583070
# 4     0.716626 -0.176091 -0.319415
# 5    -0.974091 -0.458677  0.203684
# 6    -0.444945  0.433427  0.269263
# 7    -1.417488 -0.561283  1.196632
# 8     0.560407 -0.159346  0.340378
# 9    -0.000639  2.152312 -0.696502
# 10   -1.143520 -0.416791 -0.360203
# 11   -0.108056 -0.054755 -0.387450
# 12   -0.131330  0.208675  0.402103
# 13    0.598735 -0.199857 -1.880986
# 14    0.643705 -0.236881  0.124225
# 15    0.337318 -0.030240 -1.607328
# 16   -0.247934 -0.171157  0.623018
# 17    0.966181  0.779540 -1.504230
# 18    0.147791 -0.754565 -0.433321
# 19    0.474941 -1.140034  2.040277
# 20    0.184321 -1.120403  1.995891
# 21   -0.047143 -0.174243 -0.010105
# 22   -1.744737  0.408567 -0.552765
# 23   -0.348523  1.765160 -1.335277
# 24   -1.012560  0.386199  0.053981
# 25   -0.384027  2.101717  0.444030
# 26    0.413662 -0.124183 -0.379900
# 27   -2.444216 -2.821666 -0.297236
# 28   -2.060180  0.459616 -0.397512
# 29   -1.547918  1.483501 -1.461249
# ...        ...       ...       ...
# 9970 -0.067931  1.829975  0.993774
# 9971 -0.607740  0.806059 -0.556643
# 9972 -1.784693  0.344850 -0.295022
# 9973 -1.507122  0.927593 -0.432475
# 9974 -0.869015  0.301189  0.347263
# 9975 -1.510749  0.553263  0.365347
# 9976 -1.774363  1.748445  0.353556
# 9977 -0.021801 -0.392148  1.157212
# 9978 -1.156504 -0.896311 -1.816860
# 9979  0.661284  1.428481 -1.351350
# 9980 -0.510889  1.677832 -0.002245
# 9981  0.527979 -0.512318 -0.416424
# 9982  2.410955  0.510147  1.141307
# 9983  1.487261 -0.810215 -0.450970
# 9984 -1.015778  0.300701 -1.202953
# 9985  1.093156 -0.611406  0.218881
# 9986 -0.616863 -2.248580 -0.102387
# 9987 -0.016383  0.057374 -0.470309
# 9988 -0.328756 -0.173004 -1.283157
# 9989 -1.668955 -0.536225  0.547713
# 9990  0.033469  0.241632  0.992749
# 9991 -0.689799  0.600146 -1.001609
# 9992 -0.810974  0.329747 -0.256232
# 9993 -1.050657  0.540046  0.012959
# 9994  0.334379  1.227255  1.205469
# 9995  0.851388  0.096071 -0.832659
# 9996  0.378726  0.179165  0.166011
# 9997  0.214528  0.073129 -1.405386
# 9998  0.902411 -0.640259  0.178461
# 9999 -0.747752 -0.660477  0.205842
#
# [10000 rows x 3 columns]

# %%
cond = np.abs(df) >df.std()*3
cond
# Out:
#           0      1      2
# 0     False  False  False
# 1     False  False  False
# 2     False  False  False
# 3     False  False  False
# 4     False  False  False
# 5     False  False  False
# 6     False  False  False
# 7     False  False  False
# 8     False  False  False
# 9     False  False  False
# 10    False  False  False
# 11    False  False  False
# 12    False  False  False
# 13    False  False  False
# 14    False  False  False
# 15    False  False  False
# 16    False  False  False
# 17    False  False  False
# 18    False  False  False
# 19    False  False  False
# 20    False  False  False
# 21    False  False  False
# 22    False  False  False
# 23    False  False  False
# 24    False  False  False
# 25    False  False  False
# 26    False  False  False
# 27    False  False  False
# 28    False  False  False
# 29    False  False  False
# ...     ...    ...    ...
# 9970  False  False  False
# 9971  False  False  False
# 9972  False  False  False
# 9973  False  False  False
# 9974  False  False  False
# 9975  False  False  False
# 9976  False  False  False
# 9977  False  False  False
# 9978  False  False  False
# 9979  False  False  False
# 9980  False  False  False
# 9981  False  False  False
# 9982  False  False  False
# 9983  False  False  False
# 9984  False  False  False
# 9985  False  False  False
# 9986  False  False  False
# 9987  False  False  False
# 9988  False  False  False
# 9989  False  False  False
# 9990  False  False  False
# 9991  False  False  False
# 9992  False  False  False
# 9993  False  False  False
# 9994  False  False  False
# 9995  False  False  False
# 9996  False  False  False
# 9997  False  False  False
# 9998  False  False  False
# 9999  False  False  False
#
# [10000 rows x 3 columns]

# %%
drop_index = df[cond.any(axis = 1)].index

# %%
df2 = df.drop(drop_index)

# %%
df2.shape
# Out:
# (9917, 3)

# %%
cond2 = np.abs(df2) > df.std()*3

# %%
cond2.any(axis = 1).sum()
# Out:
# 0

# %%
df2
# Out:
#              0         1         2
# 0    -1.126422 -0.919361  0.668098
# 1    -0.585425 -0.261040 -0.490388
# 2    -1.014050  0.249440  0.316363
# 3     0.729656  0.329345 -0.583070
# 4     0.716626 -0.176091 -0.319415
# 5    -0.974091 -0.458677  0.203684
# 6    -0.444945  0.433427  0.269263
# 7    -1.417488 -0.561283  1.196632
# 8     0.560407 -0.159346  0.340378
# 9    -0.000639  2.152312 -0.696502
# 10   -1.143520 -0.416791 -0.360203
# 11   -0.108056 -0.054755 -0.387450
# 12   -0.131330  0.208675  0.402103
# 13    0.598735 -0.199857 -1.880986
# 14    0.643705 -0.236881  0.124225
# 15    0.337318 -0.030240 -1.607328
# 16   -0.247934 -0.171157  0.623018
# 17    0.966181  0.779540 -1.504230
# 18    0.147791 -0.754565 -0.433321
# 19    0.474941 -1.140034  2.040277
# 20    0.184321 -1.120403  1.995891
# 21   -0.047143 -0.174243 -0.010105
# 22   -1.744737  0.408567 -0.552765
# 23   -0.348523  1.765160 -1.335277
# 24   -1.012560  0.386199  0.053981
# 25   -0.384027  2.101717  0.444030
# 26    0.413662 -0.124183 -0.379900
# 27   -2.444216 -2.821666 -0.297236
# 28   -2.060180  0.459616 -0.397512
# 29   -1.547918  1.483501 -1.461249
# ...        ...       ...       ...
# 9970 -0.067931  1.829975  0.993774
# 9971 -0.607740  0.806059 -0.556643
# 9972 -1.784693  0.344850 -0.295022
# 9973 -1.507122  0.927593 -0.432475
# 9974 -0.869015  0.301189  0.347263
# 9975 -1.510749  0.553263  0.365347
# 9976 -1.774363  1.748445  0.353556
# 9977 -0.021801 -0.392148  1.157212
# 9978 -1.156504 -0.896311 -1.816860
# 9979  0.661284  1.428481 -1.351350
# 9980 -0.510889  1.677832 -0.002245
# 9981  0.527979 -0.512318 -0.416424
# 9982  2.410955  0.510147  1.141307
# 9983  1.487261 -0.810215 -0.450970
# 9984 -1.015778  0.300701 -1.202953
# 9985  1.093156 -0.611406  0.218881
# 9986 -0.616863 -2.248580 -0.102387
# 9987 -0.016383  0.057374 -0.470309
# 9988 -0.328756 -0.173004 -1.283157
# 9989 -1.668955 -0.536225  0.547713
# 9990  0.033469  0.241632  0.992749
# 9991 -0.689799  0.600146 -1.001609
# 9992 -0.810974  0.329747 -0.256232
# 9993 -1.050657  0.540046  0.012959
# 9994  0.334379  1.227255  1.205469
# 9995  0.851388  0.096071 -0.832659
# 9996  0.378726  0.179165  0.166011
# 9997  0.214528  0.073129 -1.405386
# 9998  0.902411 -0.640259  0.178461
# 9999 -0.747752 -0.660477  0.205842
#
# [9917 rows x 3 columns]

# %%
#标准偏差的平均值
row_std_mean = df2.std(axis = 1).mean()

# %%
cond3 = df2.std(axis = 1) > row_std_mean*2.5

# %%
#一下行，的数据的标准偏差大于平均标准偏差的2.5 过滤掉
large_std_index = df2[cond3].index

# %%
df3 = df2.drop(large_std_index)

# %%
df3.shape
# Out:
# (9866, 3)

# %% [markdown]
# ## 4. 排序

# %% [markdown]
# 使用.take()函数排序
#
# 可以借助np.random.permutation()函数随机排序

# %%
df = DataFrame(np.random.randint(0,150,size = (4,4)),columns=['Python','Java','PHP','HTML'],
               index = ['张三','旭日','阳刚','木兰'])
df
# Out:
#     Python  Java  PHP  HTML
# 张三     142    50  147   128
# 旭日      17    29   24    60
# 阳刚      48   130   14   110
# 木兰      14    35  101    53

# %%
df.take([3,2,0])
# Out:
#     Python  Java  PHP  HTML
# 木兰      14    35  101    53
# 阳刚      48   130   14   110
# 张三     142    50  147   128

# %%
indices = np.random.permutation(4)

# %%
#此时得到了重新排列的数据
df.take(indices)
# Out:
#     Python  Java  PHP  HTML
# 张三     142    50  147   128
# 木兰      14    35  101    53
# 阳刚      48   130   14   110
# 旭日      17    29   24    60

# %% [markdown]
# ### 随机抽样

# %% [markdown]
# 当DataFrame规模足够大时，直接使用np.random.randint()函数，就配合take()函数实现随机抽样

# %%
df2 = DataFrame(np.random.randn(10000,3))
df2
# Out:
#              0         1         2
# 0     0.276699  0.419327  0.086632
# 1    -1.163483 -0.470376 -0.455511
# 2    -0.005259  1.080291 -0.417497
# 3     0.910627 -0.294704  0.430604
# 4    -0.903356 -1.956186  0.252204
# 5    -1.103340  1.105152 -1.684500
# 6    -2.895341  0.852676  0.843543
# 7    -0.484271 -0.347173 -1.758386
# 8    -0.190423  1.536464  0.248842
# 9     1.929386  1.455515 -0.686408
# 10    1.821788 -0.023694 -0.507512
# 11   -0.248479 -1.118258 -1.187470
# 12   -1.229486  0.151629 -0.566935
# 13   -1.304698 -1.801290 -1.139261
# 14   -2.133748 -0.625826  0.897518
# 15   -0.278677 -0.233438  0.298806
# 16   -1.206028 -0.352154 -1.677383
# 17   -1.244487  1.017201  0.777310
# 18    0.430165  1.090619  0.579926
# 19   -1.034516  0.065575  0.644076
# 20    1.122223 -0.360790 -1.062109
# 21   -0.072028  0.374390 -0.149151
# 22    0.928406  0.612910 -1.598018
# 23   -0.581994  0.335946 -1.517344
# 24   -1.813159  0.659040  0.076198
# 25    0.280368 -0.426056 -0.384182
# 26   -0.591510 -0.090252  1.361998
# 27    0.369586  1.989943 -1.072534
# 28   -0.902548 -1.501434 -0.949361
# 29   -0.957876 -0.675042 -0.638961
# ...        ...       ...       ...
# 9970  0.794475 -0.391063  0.890843
# 9971 -0.467094 -1.833625  1.281624
# 9972 -0.239302  0.710305 -0.171873
# 9973 -0.030407 -1.179722 -1.432818
# 9974  0.589215  0.372423  0.563411
# 9975  0.979343  0.000957 -0.360390
# 9976  0.167144  0.515892  0.499285
# 9977 -1.493875 -1.324355  0.671466
# 9978  1.096476 -1.750959 -0.041945
# 9979  0.169583  1.120215  1.076695
# 9980  1.051750  0.126253 -0.464133
# 9981 -0.836140  0.050942  0.695387
# 9982 -0.186238  1.819208  0.217536
# 9983 -1.095959 -0.392664  1.237920
# 9984 -0.504159  1.191238  0.549645
# 9985  0.661076  0.116912 -1.424630
# 9986  0.398455 -0.481441 -2.030706
# 9987 -0.030158  0.917029 -0.236518
# 9988 -0.543205 -0.006496 -0.466873
# 9989  0.313488 -0.691689  0.891539
# 9990 -0.643894  0.068614 -0.340291
# 9991 -1.928368 -0.471827 -2.147741
# 9992  0.864296  0.603265  0.350481
# 9993 -0.239744 -0.400466  1.061179
# 9994 -1.673395  0.753590  0.795434
# 9995 -0.170889 -1.608308  0.390133
# 9996  1.775438  0.024464 -0.824900
# 9997  1.286632  1.256028  1.491935
# 9998  0.190603  2.652744 -0.093352
# 9999  1.000560 -0.966550 -0.317381
#
# [10000 rows x 3 columns]

# %%
indices = np.random.randint(0,10000,size = 10)
df2.take(indices)
# Out:
#              0         1         2
# 4385 -0.172053  0.708154 -1.023976
# 9711  1.008797 -0.190119  1.300144
# 2613 -1.222124 -1.244814 -0.485013
# 1152 -0.009653 -0.176749  0.931804
# 4680  0.360396 -0.029017 -0.928102
# 3478  0.326191  1.277691  2.622012
# 8641 -0.145429 -2.258976  0.842130
# 3712 -2.190806  0.657491  0.823239
# 1442  0.263346  0.137804  1.140360
# 5137  1.572660  0.590736  0.254790

# %% [markdown]
# ============================================
# 练习22：
#
#    假设有张三李四王老五的期中考试成绩ddd2，对着三名同学随机排序
#
# ============================================

# %% [markdown]
# ## 5. 数据聚合【重点】

# %% [markdown]
# 数据聚合是数据处理的最后一步，通常是要使每一个数组生成一个单一的数值。
#
# 数据分类处理：
#
#  - 分组：先把数据分为几组
#  - 用函数处理：为不同组的数据应用不同的函数以转换数据
#  - 合并：把不同组得到的结果合并起来
#
# 数据分类处理的核心：
#      groupby()函数

# %%
df.std()
# Out:
# Python    59.840761
# Java      46.840154
# PHP       63.595073
# HTML      36.935755
# dtype: float64

# %%
df.mean()
# Out:
# Python    55.25
# Java      61.00
# PHP       71.50
# HTML      87.75
# dtype: float64

# %%
df2.max()
# Out:
# 0    4.602212
# 1    3.747098
# 2    3.589108
# dtype: float64

# %% [markdown]
# 如果想使用color列索引，计算price1的均值，可以先获取到price1列，然后再调用groupby函数，用参数指定color这一列

# %%
#groupby（）根据某个属性，或者多个属性进行分类
df = DataFrame({'color':['red','white','red','cyan','cyan','green','white','cyan'],
                'price':np.random.randint(0,8,size = 8),
                'weight':np.random.randint(50,55,size = 8)})
df
# Out:
#    color  price  weight
# 0    red      1      52
# 1  white      6      52
# 2    red      5      51
# 3   cyan      1      53
# 4   cyan      1      51
# 5  green      2      53
# 6  white      3      52
# 7   cyan      2      53

# %% [markdown]
# 使用.groups属性查看各行的分组情况：

# %%
#根据颜色对数据进行分类，目的计算机，将相同的事物进行分组，求和，求平局值
df_sum_weight = df.groupby(['color'])[['weight']].sum()

df_price_mean = df.groupby(['color'])[['price']].mean()

# %%
df_sum_weight
# Out:
#        weight
# color
# cyan      157
# green      53
# red       103
# white     104

# %%
df_sum_weight
# Out:
# color
# cyan     157
# green     53
# red      103
# white    104
# Name: weight, dtype: int64

# %%
df_price_mean
# Out:
#           price
# color
# cyan   1.333333
# green  2.000000
# red    3.000000
# white  4.500000

# %%
#pandas 聚合concat//append;merge

# %%
pd.concat([df,df_sum_weight],axis=1)
# Out:
#        color  price  weight  weight
# 0        red    1.0    52.0     NaN
# 1      white    6.0    52.0     NaN
# 2        red    5.0    51.0     NaN
# 3       cyan    1.0    53.0     NaN
# 4       cyan    1.0    51.0     NaN
# 5      green    2.0    53.0     NaN
# 6      white    3.0    52.0     NaN
# 7       cyan    2.0    53.0     NaN
# cyan     NaN    NaN     NaN   157.0
# green    NaN    NaN     NaN    53.0
# red      NaN    NaN     NaN   103.0
# white    NaN    NaN     NaN   104.0

# %%
type(df_sum_weight)
# Out:
# pandas.core.series.Series

# %%
df_sum = df.merge(df_sum_weight,left_on='color',right_index=True,suffixes=['','_sum'])

# %%
#平均价格进行整合
df_r = df_sum.merge(df_price_mean,left_on='color',right_index=True,suffixes=['','_平均'])

# %%
df_r
# Out:
#    color  price  weight  weight_sum  price_平均
# 0    red      1      52         103  3.000000
# 2    red      5      51         103  3.000000
# 1  white      6      52         104  4.500000
# 6  white      3      52         104  4.500000
# 3   cyan      1      53         157  1.333333
# 4   cyan      1      51         157  1.333333
# 7   cyan      2      53         157  1.333333
# 5  green      2      53          53  2.000000

# %%
#take获取，提取，take根据传入参数获取部分的数据，获取之后，自身并没有进行排序

# %%
df_r.index
# Out:
# Int64Index([0, 2, 1, 6, 3, 4, 7, 5], dtype='int64')

# %%
df_r.take([2,3])
# Out:
#    color  price  weight  weight_sum  price_平均
# 1  white      6      52         104       4.5
# 6  white      3      52         104       4.5

# %%
df_r.sort_index()
# Out:
#    color  price  weight  weight_sum  price_平均
# 0    red      1      52         103  3.000000
# 1  white      6      52         104  4.500000
# 2    red      5      51         103  3.000000
# 3   cyan      1      53         157  1.333333
# 4   cyan      1      51         157  1.333333
# 5  green      2      53          53  2.000000
# 6  white      3      52         104  4.500000
# 7   cyan      2      53         157  1.333333

# %% [markdown]
# ============================================
#
# 练习23：
#
#    假设菜市场张大妈在卖菜，有以下属性：
#
#    菜品(item)：萝卜，白菜，辣椒，冬瓜
#
#    颜色(color)：白，青，红
#
#    重量(weight)
#
#    价格(price)
#
# 1. 要求以属性作为列索引，新建一个ddd
# 2. 对ddd进行聚合操作，求出颜色为白色的价格总和
# 3. 对ddd进行聚合操作，求出萝卜的所有重量(包括白萝卜，胡萝卜，青萝卜）以及平均价格
# 4. 使用merge合并总重量及平均价格
#
# ============================================

# %% [markdown]
# ## 6.0 高级数据聚合

# %% [markdown]
# 可以使用pd.merge()函数将聚合操作的计算结果添加到df的每一行
# 使用groupby分组后调用加和等函数进行运算，让后最后可以调用add_prefix()，来修改列名

# %% [markdown]
# ### 可以使用transform和apply实现相同功能

# %% [markdown]
# 在transform或者apply中传入函数即可

# %%
sum([10])
# Out:
# 10

# %%
df['columns'] = df['color'].map()

# %%
#传递函数，这个和上午map(不能迭代) 
df.groupby('color').transform(sum)
# Out:
#    price  weight
# 0      6     103
# 1      9     104
# 2      6     103
# 3      4     157
# 4      4     157
# 5      2      53
# 6      9     104
# 7      4     157

# %%
df
# Out:
#    color  price  weight
# 0    red      1      52
# 1  white      6      52
# 2    red      5      51
# 3   cyan      1      53
# 4   cyan      1      51
# 5  green      2      53
# 6  white      3      52
# 7   cyan      2      53

# %%
df.groupby('color')[['price','weight']].apply(sum)
# Out:
#        price  weight
# color
# cyan       4     157
# green      2      53
# red        6     103
# white      9     104

# %% [markdown]
# ============================================
#
# 练习24：
#
#    使用transform与apply实现练习23的功能
#
# ============================================
