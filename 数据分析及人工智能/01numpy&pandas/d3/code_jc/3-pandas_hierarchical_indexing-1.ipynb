# %% [markdown]
# # pandas层次化索引

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ## 1. 创建多层行索引

# %% [markdown]
# ### 1) 隐式构造
#
# 最常见的方法是给DataFrame构造函数的index参数传递两个或更多的数组

# %%
index = [['一班', '一班', '一班', '二班', '二班', '二班'], ['张三', '李四', '王五', '赵六', '田七', '孙八']]
columns = [['期中', '期中', '期中', '期末', '期末', '期末'], ['语文', '数学', '英语', '语文', '数学', '英语']]
data = np.random.randint(0,150, size=(6,6))
df = DataFrame(data=data, index=index, columns=columns)
df
# Out:
#         期中             期末
#         语文   数学   英语   语文   数学   英语
# 一班 张三   69  136  129   27   15  127
#    李四  143  128   25   52  147    5
#    王五   19   46  140   18   98   72
# 二班 赵六   37   62   62  134  139   44
#    田七   70   93   56   74   43   69
#    孙八   70   44   27   12   29   85

# %% [markdown]
# - Series也可以创建多层索引

# %%
index = [['一班', '一班', '一班', '二班', '二班', '二班'], ['张三', '李四', '王五', '赵六', '田七', '孙八']]
data = np.random.randint(0,150, size=6)
s = Series(data=data, index=index)
s
# Out:
# 一班  张三     17
#     李四     34
#     王五    130
# 二班  赵六     45
#     田七     93
#     孙八     96
# dtype: int32

# %% [markdown]
# ### 2) 显示构造pd.MultiIndex

# %% [markdown]
# - 使用数组

# %%
index = pd.MultiIndex.from_arrays([['一班', '一班', '一班', '二班', '二班', '二班'], ['张三', '李四', '王五', '赵六', '田七', '孙八']])
columns = [['期中', '期中', '期中', '期末', '期末', '期末'], ['语文', '数学', '英语', '语文', '数学', '英语']]
data = np.random.randint(0,150, size=(6,6))
df = DataFrame(data=data, index=index, columns=columns)
df
# Out:
#         期中             期末
#         语文   数学   英语   语文   数学   英语
# 一班 张三  126  114  147  104   86   84
#    李四   74   36  133  108  102   18
#    王五   31   18  137  124   10  127
# 二班 赵六   34    9   66   13   57  118
#    田七  101   44   19  138  127  107
#    孙八  116  110  144  133  141   48

# %% [markdown]
# - 使用tuple

# %%
index = pd.MultiIndex.from_tuples([('一班', '张三'), ('一班', '李四'), ('一班', '王五'), ('二班', '赵六'), ('二班', '田七'), ('二班', '孙八')])
columns = [['期中', '期中', '期中', '期末', '期末', '期末'], ['语文', '数学', '英语', '语文', '数学', '英语']]
data = np.random.randint(0,150, size=(6,6))
df = DataFrame(data=data, index=index, columns=columns)
df
# Out:
#         期中             期末
#         语文   数学   英语   语文   数学   英语
# 一班 张三   56  121   13   69    8  103
#    李四   44   31  147    6   53  145
#    王五  122    1   21   34  116    9
# 二班 赵六   82  126   42  120   79   10
#    田七  107  129   33   80   32   37
#    孙八   79   83  134  102   83   56

# %% [markdown]
# - 使用product
#
#     最简单，推荐使用

# %%
index = pd.MultiIndex.from_arrays([['一班', '一班', '一班', '二班', '二班', '二班'], ['张三', '李四', '王五', '赵六', '田七', '孙八']])
columns = pd.MultiIndex.from_product([['期中', '期末'], ['语文', '数学', '英语']])
data = np.random.randint(0,150, size=(6,6))
df = DataFrame(data=data, index=index, columns=columns)
df
# Out:
#         期中            期末
#         语文   数学   英语  语文   数学   英语
# 一班 张三   83  145   19  87    3    2
#    李四   29   94   78  44   98   44
#    王五  119   72   54  17   80    6
# 二班 赵六   92   74   20  99   98   39
#    田七   25   38  111  92  137   46
#    孙八   60   95    2  42  110  132

# %% [markdown]
# ============================================
#
# 练习8：
#
# 1. 创建一个DataFrame，表示出张三李四期中期末各科成绩
#
# ============================================

# %% [markdown]
# ## 2. 多层列索引

# %% [markdown]
# 除了行索引index，列索引columns也能用同样的方法创建多层索引

# %% [markdown]
# ## 3. 多层索引对象的索引与切片操作

# %% [markdown]
# ### 1）Series的操作

# %% [markdown]
# 【重要】对于Series来说，直接中括号[]与使用.loc()完全一样，推荐使用中括号索引和切片。

# %%
s
# Out:
# 一班  张三     17
#     李四     34
#     王五    130
# 二班  赵六     45
#     田七     93
#     孙八     96
# dtype: int32

# %% [markdown]
# (1) 索引

# %%
s['张三']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\1901\.env\lib\site-packages\pandas\core\indexes\multi.py in get_value(self, series, key)
#    1318             try:
# -> 1319                 return libindex.get_value_at(s, k)
#    1320             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-2e89549a8d10> in <module>
# ----> 1 s['张三']
#
# e:\1901\.env\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# e:\1901\.env\lib\site-packages\pandas\core\indexes\multi.py in get_value(self, series, key)
#    1325                     raise InvalidIndexError(key)
#    1326                 else:
# -> 1327                     raise e1
#    1328             except Exception:  # pragma: no cover
#    1329                 raise e1
#
# e:\1901\.env\lib\site-packages\pandas\core\indexes\multi.py in get_value(self, series, key)
#    1309
#    1310         try:
# -> 1311             return self._engine.get_value(s, k)
#    1312         except KeyError as e1:
#    1313             try:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# KeyError: '张三'

# %%
s.loc['张三'] # 不能直接索引内层索引.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\1901\.env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '张三'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-73495c5352aa> in <module>
# ----> 1 s.loc['张三']
#
# e:\1901\.env\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# e:\1901\.env\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# e:\1901\.env\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     135             # but will fail when the index is not present
#     136             # see GH5667
# --> 137             return self.obj._xs(label, axis=axis)
#     138         elif isinstance(label, tuple) and isinstance(label[axis], slice):
#     139             raise IndexingError('no slices here, handle elsewhere')
#
# e:\1901\.env\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3581         if isinstance(index, MultiIndex):
#    3582             loc, new_index = self.index.get_loc_level(key,
# -> 3583                                                       drop_level=drop_level)
#    3584         else:
#    3585             loc = self.index.get_loc(key)
#
# e:\1901\.env\lib\site-packages\pandas\core\indexes\multi.py in get_loc_level(self, key, level, drop_level)
#    2569                 return indexer, maybe_droplevels(indexer, ilevels, drop_level)
#    2570         else:
# -> 2571             indexer = self._get_level_indexer(key, level=level)
#    2572             return indexer, maybe_droplevels(indexer, [level], drop_level)
#    2573
#
# e:\1901\.env\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    2650         else:
#    2651
# -> 2652             code = level_index.get_loc(key)
#    2653
#    2654             if level > 0 or self.lexsort_depth == 0:
#
# e:\1901\.env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '张三'

# %%
s.loc['一班'].loc['张三']
# Out:
# 17

# %%
s.loc['一班', '张三'] # 推荐写法
# Out:
# 17

# %%
s.iloc[[0]]
# Out:
# 一班  张三    17
# dtype: int32

# %% [markdown]
# (2) 切片

# %%
s.loc['张三': '王五'] # 没报错,但是没结果.不要直接对内层索引进行切片.
# Out:
# Series([], dtype: int32)

# %%
s.loc['一班':]
# Out:
# 一班  张三     17
#     李四     34
#     王五    130
# 二班  赵六     45
#     田七     93
#     孙八     96
# dtype: int32

# %%
s.loc['一班']
# Out:
# 张三     17
# 李四     34
# 王五    130
# dtype: int32

# %%
s.iloc[0:4]
# Out:
# 一班  张三     17
#     李四     34
#     王五    130
# 二班  赵六     45
# dtype: int32

# %% [markdown]
# ### 2）DataFrame的操作

# %%
df
# Out:
#         期中            期末
#         语文   数学   英语  语文   数学   英语
# 一班 张三   83  145   19  87    3    2
#    李四   29   94   78  44   98   44
#    王五  119   72   54  17   80    6
# 二班 赵六   92   74   20  99   98   39
#    田七   25   38  111  92  137   46
#    孙八   60   95    2  42  110  132

# %% [markdown]
# (1) 可以直接使用列名称来进行列索引

# %%
df['期中']
# Out:
#         语文   数学   英语
# 一班 张三   83  145   19
#    李四   29   94   78
#    王五  119   72   54
# 二班 赵六   92   74   20
#    田七   25   38  111
#    孙八   60   95    2

# %%
df['语文'] # DataFrame也是不能直接索引内层索引.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\1901\.env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '语文'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-1ec98355347e> in <module>
# ----> 1 df['语文']
#
# e:\1901\.env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2924         if is_single_key:
#    2925             if self.columns.nlevels > 1:
# -> 2926                 return self._getitem_multilevel(key)
#    2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#
# e:\1901\.env\lib\site-packages\pandas\core\frame.py in _getitem_multilevel(self, key)
#    2970
#    2971     def _getitem_multilevel(self, key):
# -> 2972         loc = self.columns.get_loc(key)
#    2973         if isinstance(loc, (slice, Series, np.ndarray, Index)):
#    2974             new_columns = self.columns[loc]
#
# e:\1901\.env\lib\site-packages\pandas\core\indexes\multi.py in get_loc(self, key, method)
#    2395
#    2396         if not isinstance(key, tuple):
# -> 2397             loc = self._get_level_indexer(key, level=0)
#    2398             return _maybe_to_slice(loc)
#    2399
#
# e:\1901\.env\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    2650         else:
#    2651
# -> 2652             code = level_index.get_loc(key)
#    2653
#    2654             if level > 0 or self.lexsort_depth == 0:
#
# e:\1901\.env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '语文'

# %%
df['期中']['语文']
# Out:
# 一班  张三     83
#     李四     29
#     王五    119
# 二班  赵六     92
#     田七     25
#     孙八     60
# Name: 语文, dtype: int32

# %%
df['期中', '语文']
# Out:
# 一班  张三     83
#     李四     29
#     王五    119
# 二班  赵六     92
#     田七     25
#     孙八     60
# Name: (期中, 语文), dtype: int32

# %% [markdown]
# 行多级索引的索引和切片操作

# %%
df.loc['一班']
# Out:
#      期中           期末
#      语文   数学  英语  语文  数学  英语
# 张三   83  145  19  87   3   2
# 李四   29   94  78  44  98  44
# 王五  119   72  54  17  80   6

# %%
df.loc['张三']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\1901\.env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '张三'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-65e66002fc39> in <module>
# ----> 1 df.loc['张三']
#
# e:\1901\.env\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# e:\1901\.env\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# e:\1901\.env\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# e:\1901\.env\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3581         if isinstance(index, MultiIndex):
#    3582             loc, new_index = self.index.get_loc_level(key,
# -> 3583                                                       drop_level=drop_level)
#    3584         else:
#    3585             loc = self.index.get_loc(key)
#
# e:\1901\.env\lib\site-packages\pandas\core\indexes\multi.py in get_loc_level(self, key, level, drop_level)
#    2569                 return indexer, maybe_droplevels(indexer, ilevels, drop_level)
#    2570         else:
# -> 2571             indexer = self._get_level_indexer(key, level=level)
#    2572             return indexer, maybe_droplevels(indexer, [level], drop_level)
#    2573
#
# e:\1901\.env\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    2650         else:
#    2651
# -> 2652             code = level_index.get_loc(key)
#    2653
#    2654             if level > 0 or self.lexsort_depth == 0:
#
# e:\1901\.env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '张三'

# %%
df.loc['一班'].loc['张三']
# Out:
# 期中  语文     83
#     数学    145
#     英语     19
# 期末  语文     87
#     数学      3
#     英语      2
# Name: 张三, dtype: int32

# %%
df.loc['一班', '张三']
# Out:
# 期中  语文     83
#     数学    145
#     英语     19
# 期末  语文     87
#     数学      3
#     英语      2
# Name: (一班, 张三), dtype: int32

# %% [markdown]
# 列多级索引的索引和切片操作

# %%
df
# Out:
#         期中            期末
#         语文   数学   英语  语文   数学   英语
# 一班 张三   83  145   19  87    3    2
#    李四   29   94   78  44   98   44
#    王五  119   72   54  17   80    6
# 二班 赵六   92   74   20  99   98   39
#    田七   25   38  111  92  137   46
#    孙八   60   95    2  42  110  132

# %%
df['一班': '二班']
# Out:
#         期中            期末
#         语文   数学   英语  语文   数学   英语
# 一班 张三   83  145   19  87    3    2
#    李四   29   94   78  44   98   44
#    王五  119   72   54  17   80    6
# 二班 赵六   92   74   20  99   98   39
#    田七   25   38  111  92  137   46
#    孙八   60   95    2  42  110  132

# %%
df.iloc[0:4]
# Out:
#         期中           期末
#         语文   数学  英语  语文  数学  英语
# 一班 张三   83  145  19  87   3   2
#    李四   29   94  78  44  98  44
#    王五  119   72  54  17  80   6
# 二班 赵六   92   74  20  99  98  39

# %% [markdown]
# (2) 使用行索引需要用loc[]函数
#
# 【极其重要】推荐使用loc[]函数

# %% [markdown]
# 注意在对行索引的时候，若一级行索引还有多个，对二级行索引会遇到问题！也就是说，无法直接对二级索引进行索引，必须让二级索引变成一级索引后才能对其进行索引！

# %% [markdown]
# ============================================
#
# 练习9：
#
# 1. 分析比较Series和DataFrame各种索引的方式，熟练掌握.loc()方法
#
# 2. 假设张三再一次在期中考试的时候因为特殊原因放弃英语考试，如何实现？
#
# ============================================

# %%
df
# Out:
#         期中            期末
#         语文   数学   英语  语文   数学   英语
# 一班 张三   83  145   19  87    3    2
#    李四   29   94   78  44   98   44
#    王五  119   72   54  17   80    6
# 二班 赵六   92   74   20  99   98   39
#    田七   25   38  111  92  137   46
#    孙八   60   95    2  42  110  132

# %%
df.loc['一班', '张三'].loc['期中', '英语'] = None

# %%
df
# Out:
#         期中            期末
#         语文   数学   英语  语文   数学   英语
# 一班 张三   83  145   19  87    3    2
#    李四   29   94   78  44   98   44
#    王五  119   72   54  17   80    6
# 二班 赵六   92   74   20  99   98   39
#    田七   25   38  111  92  137   46
#    孙八   60   95    2  42  110  132

# %%
df.loc['一班', '张三'].loc['期中', '英语'] = np.nan

# %%
df
# Out:
#         期中            期末
#         语文   数学   英语  语文   数学   英语
# 一班 张三   83  145   19  87    3    2
#    李四   29   94   78  44   98   44
#    王五  119   72   54  17   80    6
# 二班 赵六   92   74   20  99   98   39
#    田七   25   38  111  92  137   46
#    孙八   60   95    2  42  110  132

# %%
df.dtypes
# Out:
# 期中  语文    int32
#     数学    int32
#     英语    int32
# 期末  语文    int32
#     数学    int32
#     英语    int32
# dtype: object

# %%
df = df.astype(np.float64)

# %%
df.dtypes
# Out:
# 期中  语文    float64
#     数学    float64
#     英语    float64
# 期末  语文    float64
#     数学    float64
#     英语    float64
# dtype: object

# %%
df.loc['一班', '张三'].loc['期中', '英语'] = np.nan

# %%
df
# Out:
#           期中                  期末
#           语文     数学     英语    语文     数学     英语
# 一班 张三   83.0  145.0    NaN  87.0    3.0    2.0
#    李四   29.0   94.0   78.0  44.0   98.0   44.0
#    王五  119.0   72.0   54.0  17.0   80.0    6.0
# 二班 赵六   92.0   74.0   20.0  99.0   98.0   39.0
#    田七   25.0   38.0  111.0  92.0  137.0   46.0
#    孙八   60.0   95.0    2.0  42.0  110.0  132.0

# %% [markdown]
# ## 4. 索引的堆（stack）

# %% [markdown]
# - ``stack()``
# - ``unstack()``

# %%
df
# Out:
#           期中                  期末
#           语文     数学     英语    语文     数学     英语
# 一班 张三   83.0  145.0    NaN  87.0    3.0    2.0
#    李四   29.0   94.0   78.0  44.0   98.0   44.0
#    王五  119.0   72.0   54.0  17.0   80.0    6.0
# 二班 赵六   92.0   74.0   20.0  99.0   98.0   39.0
#    田七   25.0   38.0  111.0  92.0  137.0   46.0
#    孙八   60.0   95.0    2.0  42.0  110.0  132.0

# %%
把水平的列索引转化为行索引就叫做stack
反之叫做unstack

# %%
df.stack() # 默认level=-1表示对最里面那一层操作
# Out:
#              期中     期末
# 一班 张三 数学  145.0    3.0
#       英语    NaN    2.0
#       语文   83.0   87.0
#    李四 数学   94.0   98.0
#       英语   78.0   44.0
#       语文   29.0   44.0
#    王五 数学   72.0   80.0
#       英语   54.0    6.0
#       语文  119.0   17.0
# 二班 赵六 数学   74.0   98.0
#       英语   20.0   39.0
#       语文   92.0   99.0
#    田七 数学   38.0  137.0
#       英语  111.0   46.0
#       语文   25.0   92.0
#    孙八 数学   95.0  110.0
#       英语    2.0  132.0
#       语文   60.0   42.0

# %%
df.stack(level=0)
# Out:
#              数学     英语     语文
# 一班 张三 期中  145.0    NaN   83.0
#       期末    3.0    2.0   87.0
#    李四 期中   94.0   78.0   29.0
#       期末   98.0   44.0   44.0
#    王五 期中   72.0   54.0  119.0
#       期末   80.0    6.0   17.0
# 二班 赵六 期中   74.0   20.0   92.0
#       期末   98.0   39.0   99.0
#    田七 期中   38.0  111.0   25.0
#       期末  137.0   46.0   92.0
#    孙八 期中   95.0    2.0   60.0
#       期末  110.0  132.0   42.0

# %%
df
# Out:
#           期中                  期末
#           语文     数学     英语    语文     数学     英语
# 一班 张三   83.0  145.0    NaN  87.0    3.0    2.0
#    李四   29.0   94.0   78.0  44.0   98.0   44.0
#    王五  119.0   72.0   54.0  17.0   80.0    6.0
# 二班 赵六   92.0   74.0   20.0  99.0   98.0   39.0
#    田七   25.0   38.0  111.0  92.0  137.0   46.0
#    孙八   60.0   95.0    2.0  42.0  110.0  132.0

# %%
df.unstack(fill_value=0)
# Out:
#       期中                                 ...     期末
#       语文                                 ...     英语
#       孙八    张三    李四     王五    田七    赵六  ...     孙八   张三    李四   王五    田七    赵六
# 一班   0.0  83.0  29.0  119.0   0.0   0.0  ...    0.0  2.0  44.0  6.0   0.0   0.0
# 二班  60.0   0.0   0.0    0.0  25.0  92.0  ...  132.0  0.0   0.0  0.0  46.0  39.0
#
# [2 rows x 36 columns]

# %%
df.unstack(level=0, fill_value=0)
# Out:
#        期中                                    期末
#        语文           数学          英语           语文          数学           英语
#        一班    二班     一班    二班    一班     二班    一班    二班    一班     二班    一班     二班
# 孙八    0.0  60.0    0.0  95.0   0.0    2.0   0.0  42.0   0.0  110.0   0.0  132.0
# 张三   83.0   0.0  145.0   0.0   NaN    0.0  87.0   0.0   3.0    0.0   2.0    0.0
# 李四   29.0   0.0   94.0   0.0  78.0    0.0  44.0   0.0  98.0    0.0  44.0    0.0
# 王五  119.0   0.0   72.0   0.0  54.0    0.0  17.0   0.0  80.0    0.0   6.0    0.0
# 田七    0.0  25.0    0.0  38.0   0.0  111.0   0.0  92.0   0.0  137.0   0.0   46.0
# 赵六    0.0  92.0    0.0  74.0   0.0   20.0   0.0  99.0   0.0   98.0   0.0   39.0

# %% [markdown]
# 小技巧】使用stack()的时候，level等于哪一个，哪一个就消失，出现在行里。

# %% [markdown]
# 【小技巧】使用unstack()的时候，level等于哪一个，哪一个就消失，出现在列里。

# %% [markdown]
# ============================================
#
# 练习10：
#
# 1. 使用unstack()将ddd变为两行，分别为期中期末
#
# 2. 使用unstack()将ddd变为四行，分别为四个科目
#
# ============================================

# %%
df
# Out:
#           期中                  期末
#           语文     数学     英语    语文     数学     英语
# 一班 张三   83.0  145.0    NaN  87.0    3.0    2.0
#    李四   29.0   94.0   78.0  44.0   98.0   44.0
#    王五  119.0   72.0   54.0  17.0   80.0    6.0
# 二班 赵六   92.0   74.0   20.0  99.0   98.0   39.0
#    田七   25.0   38.0  111.0  92.0  137.0   46.0
#    孙八   60.0   95.0    2.0  42.0  110.0  132.0

# %%
df.stack(level=0).unstack(level=0, fill_value=0).unstack(level=0)
# Out:
#      数学                               ...    语文
#      一班                               ...    二班
#      孙八     张三    李四    王五   田七   赵六  ...    孙八   张三   李四   王五    田七    赵六
# 期中  0.0  145.0  94.0  72.0  0.0  0.0  ...  60.0  0.0  0.0  0.0  25.0  92.0
# 期末  0.0    3.0  98.0  80.0  0.0  0.0  ...  42.0  0.0  0.0  0.0  92.0  99.0
#
# [2 rows x 36 columns]

# %%
df
# Out:
#           期中                  期末
#           语文     数学     英语    语文     数学     英语
# 一班 张三   83.0  145.0    NaN  87.0    3.0    2.0
#    李四   29.0   94.0   78.0  44.0   98.0   44.0
#    王五  119.0   72.0   54.0  17.0   80.0    6.0
# 二班 赵六   92.0   74.0   20.0  99.0   98.0   39.0
#    田七   25.0   38.0  111.0  92.0  137.0   46.0
#    孙八   60.0   95.0    2.0  42.0  110.0  132.0

# %%
df.stack().unstack(level=0, fill_value=0).unstack(level=0)
# Out:
#      期中                                ...     期末
#      一班                                ...     二班
#      孙八     张三    李四     王五   田七   赵六  ...     孙八   张三   李四   王五     田七    赵六
# 数学  0.0  145.0  94.0   72.0  0.0  0.0  ...  110.0  0.0  0.0  0.0  137.0  98.0
# 英语  0.0    NaN  78.0   54.0  0.0  0.0  ...  132.0  0.0  0.0  0.0   46.0  39.0
# 语文  0.0   83.0  29.0  119.0  0.0  0.0  ...   42.0  0.0  0.0  0.0   92.0  99.0
#
# [3 rows x 24 columns]

# %% [markdown]
# ## 5. 聚合操作

# %% [markdown]
# 【注意】
#
# - 需要指定axis
#
# - 【小技巧】和unstack()相反，聚合的时候，axis等于哪一个，哪一个就保留。

# %%
sum mean max min std  var

# %%
df
# Out:
#           期中                  期末
#           语文     数学     英语    语文     数学     英语
# 一班 张三   83.0  145.0    NaN  87.0    3.0    2.0
#    李四   29.0   94.0   78.0  44.0   98.0   44.0
#    王五  119.0   72.0   54.0  17.0   80.0    6.0
# 二班 赵六   92.0   74.0   20.0  99.0   98.0   39.0
#    田七   25.0   38.0  111.0  92.0  137.0   46.0
#    孙八   60.0   95.0    2.0  42.0  110.0  132.0

# %%
df.sum(axis=1)
# Out:
# 一班  张三    320.0
#     李四    387.0
#     王五    348.0
# 二班  赵六    422.0
#     田七    449.0
#     孙八    441.0
# dtype: float64

# %%
df.sum(axis=0, level=0) # level等于哪一层,哪一层就保留下来,其他层就被聚合掉.
# Out:
#        期中                   期末
#        语文     数学     英语     语文     数学     英语
# 一班  231.0  311.0  132.0  148.0  181.0   52.0
# 二班  177.0  207.0  133.0  233.0  345.0  217.0

# %%
df.sum(axis=1, level=0)
# Out:
#           期中     期末
# 一班 张三  228.0   92.0
#    李四  201.0  186.0
#    王五  245.0  103.0
# 二班 赵六  186.0  236.0
#    田七  174.0  275.0
#    孙八  157.0  284.0

# %%
df
# Out:
#           期中                  期末
#           语文     数学     英语    语文     数学     英语
# 一班 张三   83.0  145.0    NaN  87.0    3.0    2.0
#    李四   29.0   94.0   78.0  44.0   98.0   44.0
#    王五  119.0   72.0   54.0  17.0   80.0    6.0
# 二班 赵六   92.0   74.0   20.0  99.0   98.0   39.0
#    田七   25.0   38.0  111.0  92.0  137.0   46.0
#    孙八   60.0   95.0    2.0  42.0  110.0  132.0

# %%
# 期中期末最大值.
df.max(axis=1, level=0)
# 正常axis=0,表示行,axis=1表示列.
# Out:
#           期中     期末
# 一班 张三  145.0   87.0
#    李四   94.0   98.0
#    王五  119.0   80.0
# 二班 赵六   92.0   99.0
#    田七  111.0  137.0
#    孙八   95.0  132.0

# %% [markdown]
# 所谓的聚合操作：平均数，方差，最大值，最小值……

# %% [markdown]
# ============================================
#
# 练习11：
#
# 1. 计算各个科目期中期末平均成绩
#
# 2. 计算各科目张三李四的最高分
#
# ============================================

# %%
df.mean(axis=1, level=1)
# Out:
#          语文     数学    英语
# 一班 张三  85.0   74.0   2.0
#    李四  36.5   96.0  61.0
#    王五  68.0   76.0  30.0
# 二班 赵六  95.5   86.0  29.5
#    田七  58.5   87.5  78.5
#    孙八  51.0  102.5  67.0

# %%
df.max(level=1, axis=1)
# Out:
#           语文     数学     英语
# 一班 张三   87.0  145.0    2.0
#    李四   44.0   98.0   78.0
#    王五  119.0   80.0   54.0
# 二班 赵六   99.0   98.0   39.0
#    田七   92.0  137.0  111.0
#    孙八   60.0  110.0  132.0
