# %%
# 导包
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
# 导入数据
zero = plt.imread('./data/0/0_1.bmp')

# %%
zero.shape
# Out:
# (28, 28)

# %%
type(zero)
# Out:
# numpy.ndarray

# %%
plt.imshow(zero)

# %%
# 读取所有的bitmap图片
X_train = []
y_train = []
for i in range(10):
    for j in range(1,501):
        data = plt.imread('./data/%d/%d_%d.bmp '%( i,i,j))
        X_train.append(data)
        y_train.append(i)

# %%
# 转换成ndarray
data = np.array(X_train)
target = np.array(y_train)

# %%
display(data.shape, target.shape)
# Out:
# (5000, 28, 28)
# (5000,)

# %%
data = data.reshape((5000,-1))

# %%
data.shape
# Out:
# (5000, 784)

# %%
X_train , x_test, y_train,y_test = train_test_split(data, target, test_size=0.1)

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
# 进行预测
y_ = knn.predict(x_test)

# %%
display(y_[::5], y_test[::5])
# Out:
# array([1, 7, 1, 1, 9, 2, 5, 2, 8, 9, 1, 4, 8, 5, 6, 3, 5, 0, 0, 2, 7, 0,
#        4, 6, 4, 8, 3, 0, 4, 9, 6, 7, 3, 0, 9, 4, 1, 7, 6, 5, 6, 9, 9, 9,
#        1, 2, 1, 0, 4, 7, 7, 6, 5, 5, 4, 5, 3, 9, 6, 4, 2, 4, 0, 5, 9, 6,
#        3, 9, 6, 7, 8, 1, 7, 6, 3, 7, 0, 2, 1, 3, 5, 7, 8, 8, 9, 1, 6, 4,
#        5, 6, 1, 0, 6, 2, 5, 5, 7, 5, 2, 1])
# array([1, 7, 1, 1, 9, 2, 5, 2, 8, 9, 1, 4, 8, 5, 6, 3, 5, 0, 0, 2, 7, 0,
#        4, 6, 4, 8, 3, 0, 4, 9, 6, 7, 3, 0, 9, 4, 1, 7, 6, 5, 6, 8, 4, 9,
#        8, 2, 1, 0, 4, 7, 7, 6, 5, 5, 4, 5, 3, 9, 6, 4, 2, 4, 0, 5, 4, 6,
#        3, 9, 6, 7, 8, 7, 7, 6, 3, 2, 0, 2, 1, 3, 5, 7, 8, 2, 9, 2, 6, 4,
#        5, 6, 1, 0, 6, 2, 5, 5, 7, 5, 2, 1])

# %%
knn.score(X_train,y_train)
# Out:
# 0.9604444444444444

# %%
x_test.shape
# Out:
# (500, 784)

# %%
x_test[50].reshape((28,28))
# Out:
# array([[255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,
#         255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 219,
# ...

# %%
plt.imshow(x_test[50].reshape((28,28)))

# %%
# h画图
# 10行10列
plt.figure(figsize=(10*2, 10*3))
for  i in range(100):
    axes = plt.subplot(10,10,i+1)
    axes.imshow(x_test[i*5].reshape((28,28)),cmap='gray')
    axes.set_title('True:%d\nPredict:%d' % (y_test[i*5], y_[i*5]))
